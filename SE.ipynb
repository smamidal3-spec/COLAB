# %% [markdown]
# <a href="https://colab.research.google.com/github/smamidal3-spec/COLAB/blob/main/SE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **WEATHER MODELING SYSTEM**

# %%
def temperature_modeling(a, b, c, time):
    temperature = a * time**2 + b * time + c
    return temperature


a_hardcoded, b_hardcoded, c_hardcoded = 0.1, 2, 10

print("Hard-coded Variables for Weather Modeling")
time_hardcoded = 5
print(
    "Temperature for hardcoded coefficients at time",
    time_hardcoded,
    "hours:",
    temperature_modeling(a_hardcoded, b_hardcoded, c_hardcoded, time_hardcoded)
)
print("\n")


print("Keyboard Input for Weather Modeling")
a_keyboard = float(input("Enter coefficient a: "))
b_keyboard = float(input("Enter coefficient b: "))
c_keyboard = float(input("Enter coefficient c: "))
time_keyboard = float(input("Enter time in hours: "))

print(
    "Temperature for keyboard input coefficients at time",
    time_keyboard,
    "hours:",
    temperature_modeling(a_keyboard, b_keyboard, c_keyboard, time_keyboard)
)
print("\n")


with open("weather_data.txt", "w") as file:
    file.write("0.2 1.5 8\n")
    file.write("4\n")


with open("weather_data.txt", "r") as file:
    lines = file.readlines()
    a_file, b_file, c_file = map(float, lines[0].split())
    time_file = float(lines[1])


print("Read from File for Weather Modeling")
print(
    "Temperature for file input coefficients at time",
    time_file,
    "hours:",
    temperature_modeling(a_file, b_file, c_file, time_file)
)
print("\n")
# Out:
# Hard-coded Variables for Weather Modeling
# Temperature for hardcoded coefficients at time 5 hours: 22.5
#
#
# Keyboard Input for Weather Modeling
# Enter coefficient a: 2
# Enter coefficient b: 5
# Enter coefficient c: 3
# Enter time in hours: 2
# Temperature for keyboard input coefficients at time 2.0 hours: 21.0
#
#
# Read from File for Weather Modeling
# Temperature for file input coefficients at time 4.0 hours: 17.2

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
a = 10
b = 20

print("Sum =", a + b)
print("Product =", a * b)
# Out:
# Sum = 30
# Product = 200

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))

print("Sum =", a + b)
print("Difference =", a - b)
# Out:
# Enter first number: 3
# Enter second number: 4
# Sum = 7
# Difference = -1

# %%
with open("single_input.txt", "w") as file:
    file.write("25")

# %%
try:
    with open("single_input.txt", "r") as file:
        num = int(file.read())
    print("Number =", num)
    print("Square =", num * num)
except:
    print("Error reading file")
# Out:
# Number = 25
# Square = 625

# %%
with open("multiple_inputs.txt", "w") as file:
    file.write("10\n20\n30\n40")

# %%
try:
    with open("multiple_inputs.txt", "r") as file:
        numbers = file.readlines()

    numbers = [int(n.strip()) for n in numbers]

    print("Numbers:", numbers)
    print("Sum:", sum(numbers))
    print("Average:", sum(numbers)/len(numbers))
except:
    print("Error reading file")
# Out:
# Numbers: [10, 20, 30, 40]
# Sum: 100
# Average: 25.0

# %%
try:
    x = int(input("Enter a number: "))
    print(100 / x)
except ZeroDivisionError:
    print("Cannot divide by zero")
except ValueError:
    print("Invalid input")
# Out:
# Enter a number: 44
# 2.272727272727273

# %%
files = {
    "hardcoded.py": "a=10\nb=20\nprint(a+b)",
    "keyboard.py": "a=int(input())\nb=int(input())\nprint(a+b)",
    "single_file.py": "f=open('single_input.txt')\nprint(f.read())",
    "multiple_file.py": "f=open('multiple_inputs.txt')\nprint(f.readlines())"
}

for name, content in files.items():
    with open(name, "w") as f:
        f.write(content)

print("All versions saved")
# Out:
# All versions saved

# %%
import matplotlib.pyplot as plt
import numpy as np

# Quadratic model function
def quadratic_model(x, a, b, c):
    return a * x**2 + b * x + c

# Generate weather data with optional noise
def generate_weather_data(start, end, num_points, a, b, c, noise_factor=10):
    x = np.linspace(start, end, num_points)
    y = quadratic_model(x, a, b, c) + np.random.normal(0, noise_factor, num_points)
    return x, y

# Plot weather data
def plot_weather_data(x, y, title):
    plt.scatter(x, y, label='Weather Data')
    plt.title(title)
    plt.xlabel('Time')
    plt.ylabel('Temperature')
    plt.legend()
    plt.show()

# Example parameters for the quadratic model
a = 0.5
b = -3
c = 20

# Generate weather data
start_time = 0
end_time = 10
num_points = 100

x_data, y_data = generate_weather_data(start_time, end_time, num_points, a, b, c)

# Plot the weather data (labeled "Waterfall Model" as per your code)
plot_weather_data(x_data, y_data, 'Waterfall Model: Weather Data')

# Display the final temperature value
final_temperature = y_data[-1]
print(f"\nFinal Temperature for Waterfall Model (Example Parameters): {final_temperature}")
# Out:
# Final Temperature for Waterfall Model (Example Parameters): 58.10677451991791

# %%
import matplotlib.pyplot as plt
import numpy as np

# Quadratic temperature model
def quadratic_model(x, a, b, c):
    return a * x**2 + b * x + c

# Generate synthetic weather data
def generate_weather_data(start, end, num_points, a, b, c, noise_factor=10):
    x = np.linspace(start, end, num_points)
    y = quadratic_model(x, a, b, c) + np.random.normal(0, noise_factor, num_points)
    return x, y

# Plot weather data
def plot_weather_data(x, y, title):
    plt.scatter(x, y, label='Weather Data')
    plt.title(title)
    plt.xlabel('Time')
    plt.ylabel('Temperature')
    plt.legend()
    plt.show()

# Initial parameters for the Agile model
a_agile = 0.5
b_agile = -5
c_agile = 20

# Generate initial weather data
start_time = 0
end_time = 10
num_points = 100

x_data, y_agile = generate_weather_data(
    start_time, end_time, num_points,
    a_agile, b_agile, c_agile
)

# Initial plot
plot_weather_data(
    x_data,
    y_agile,
    'Agile Model: Initial Weather Data'
)

# Agile development
num_sprints = 3  # Adjust as needed

for sprint in range(1, num_sprints + 1):
    print(f"\nSprint {sprint}: Gather feedback and refine the model.")

    a_agile += float(input("Enter incremental change for 'a': "))
    b_agile += float(input("Enter incremental change for 'b': "))
    c_agile += float(input("Enter incremental change for 'c': "))

    # Generate updated weather data
    y_agile = quadratic_model(x_data, a_agile, b_agile, c_agile)

    # Plot updated weather data
    plot_weather_data(
        x_data,
        y_agile,
        f'Agile Model: Sprint {sprint} Weather Data'
    )

# Final plot
plot_weather_data(
    x_data,
    y_agile,
    'Agile Model: Final Weather Data'
)

# Final temperature
final_temperature_agile = y_agile[-1]
print(f"\nFinal Temperature for Agile Model: {final_temperature_agile:.2f}")
# Out:
# Sprint 1: Gather feedback and refine the model.
# Enter incremental change for 'a': 2
# Enter incremental change for 'b': 5
# Enter incremental change for 'c': 7
# Sprint 2: Gather feedback and refine the model.
# Enter incremental change for 'a': 2
# Enter incremental change for 'b': -5
# Enter incremental change for 'c': 3
# Sprint 3: Gather feedback and refine the model.
# Enter incremental change for 'a': 3
# Enter incremental change for 'b': -6
# Enter incremental change for 'c': 2
# Final Temperature for Agile Model: 672.00

# %%
# LAB 4 - Iterative Weather Modeling

import numpy as np
import matplotlib.pyplot as plt


def quadratic(x, a, b, c):
    return a * x**2 + b * x + c


def generate(start, end, num, a, b, c, noise=10):
    x = np.linspace(start, end, num)
    y = quadratic(x, a, b, c) + np.random.normal(0, noise, num)
    return x, y


def plot(x, y, title):
    plt.scatter(x, y, label="Weather Data")
    plt.title(title)
    plt.xlabel("Time")
    plt.ylabel("Temperature")
    plt.legend()
    plt.show()


# Initial Parameters
a, b, c = 0.5, -5, 20
start, end, num = 0, 10, 100

x_data, y_data = generate(start, end, num, a, b, c)
plot(x_data, y_data, "Iterative Model: Initial Weather Data")

# Iterations
num_iterations = 3

for i in range(1, num_iterations + 1):
    print(f"Iteration {i}: Gather feedback and refine the model.")
    a = float(input("Enter new value for a: "))
    b = float(input("Enter new value for b: "))
    c = float(input("Enter new value for c: "))

    y_iter = quadratic(x_data, a, b, c)
    plot(x_data, y_iter, f"Iterative Model: Iteration {i}")

plot(x_data, y_iter, "Iterative Model: Final Weather Data")
# Out:
# Iteration 1: Gather feedback and refine the model.
